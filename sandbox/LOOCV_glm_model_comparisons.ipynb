# %%
# %load_ext autoreload
# %autoreload 2

import os 
# os.environ['R_HOME']= r'C:\Users\tomha\miniconda3\envs\octagon_analysis\lib\R'
os.environ['R_HOME']= r'D:\Users\Tom\miniconda3\envs\octagon_analysis\lib\R'
# os.environ['R_HOME']=r'D:\Users\Tom\miniconda3\envs\octagon_analysis\lib\R'

import rpy2

import rpy2.robjects as robjects
print(robjects.r('R.version.string'))

import parse_data.prepare_data as prepare_data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import globals
import data_strings
import data_extraction.get_indices as get_indices
import analysis.wall_visibility_and_choice as wall_visibility_and_choice
from trajectory_analysis import trajectory_vectors
from plotting import plot_octagon
import parse_data.identify_filepaths as identify_filepaths 
from data_extraction.trial_list_filters import filter_trials_other_visible
from analysis import opponent_visibility
from ipywidgets import IntProgress
from IPython.display import display
import time
from pymer4.models import Lmer
# Out:
# [1] "R version 4.1.3 (2022-03-10)"

# %% [markdown]
# ### load data

# %%
import pickle

with open('./data/analysis_results.pkl', 'rb') as f:
    analysis_results = pickle.load(f)

# %% [markdown]
# #### Populate a dataframe, with a row for each trial, and fields for regressors (only including trials with fully-populated regressors)

# %% [markdown]
# #### Social df

# %%
glm_df_social = pd.DataFrame()

for session_id, players in analysis_results.items():
    for player_id in players:
        
        # take each filtered_regressor array and fill the relevant df field for this player
        player_data = analysis_results[session_id][player_id]['social']['regressors']
        choice = analysis_results[session_id][player_id]['social']['dependent']['choice']
        opponent_player_id = 1 if player_id == 0 else 1
        opponent_player_data = analysis_results[session_id][opponent_player_id]['social']['regressors']
        df_player = pd.DataFrame(
                    {
                        "SessionID" : session_id,
                        "PlayerID" : player_id,
                        "GlmPlayerID" : session_id*2 + player_id,
                        "ChooseHigh" : choice,
                        "WallSep" : player_data['wall_sep'],
                        "FirstSeenWall" : player_data['first_seen'],
                        "D2H" : player_data['d2h'],
                        "D2L" : player_data['d2l'],
                        "OpponentVisible" : player_data['opponent_visible'],
                        "OpponentFirstSeenWall" : player_data['first_seen_opponent'],
                        "OpponentD2H" : player_data['d2h_opponent'],
                        "OpponentD2L" : player_data['d2l_opponent']
                        
                    }
        )


        # append this smaller dataframe to the the full dataframe
        glm_df_social = pd.concat([glm_df_social, df_player], ignore_index=True)



glm_df_social["FirstSeenWall"] = glm_df_social["FirstSeenWall"].astype(str).astype("category")
glm_df_social["OpponentFirstSeenWall"] = glm_df_social["OpponentFirstSeenWall"].astype(str).astype("category")

glm_df_social["WallSep"] = glm_df_social["WallSep"].astype(str).astype("category")

# %% [markdown]
# #### solo-social combined df

# %%
glm_df_solo_social = pd.DataFrame()

for session_id, players in analysis_results.items():
    for player_id in players:
        
        # take each filtered_regressor array and fill the relevant df field for this player
        player_data_solo = analysis_results[session_id][player_id]['solo']['regressors']
        player_data_social = analysis_results[session_id][player_id]['social']['regressors']
        choice_solo = analysis_results[session_id][player_id]['solo']['dependent']['choice']
        choice_social = analysis_results[session_id][player_id]['social']['dependent']['choice']
        df_player = pd.DataFrame(
                    {
                        "SessionID" : session_id,
                        "PlayerID" : player_id,
                        "GlmPlayerID" : session_id*2 + player_id,
                        "ChooseHigh" : np.concatenate([choice_solo, choice_social]),
                        "WallSep" :  np.concatenate([player_data_solo['wall_sep'], player_data_social['wall_sep']]),
                        "FirstSeenWall" : np.concatenate([player_data_solo['first_seen'], player_data_social['first_seen']]),
                        "D2H" : np.concatenate([player_data_solo['d2h'], player_data_social['d2h']]),
                        "D2L" : np.concatenate([player_data_solo['d2l'], player_data_social['d2l']]),
                        "SocialContext" : np.concatenate([np.ones(player_data_solo["wall_sep"].shape[0]) - 1, np.ones(player_data_social["wall_sep"].shape[0])]) # 0 for solo, 1 for social
                    }
        )

        # append this smaller dataframe to the the full dataframe
        glm_df_solo_social = pd.concat([glm_df_solo_social, df_player], ignore_index=True)


glm_df_solo_social["FirstSeenWall"] = glm_df_solo_social["FirstSeenWall"].astype(str).astype("category")
glm_df_solo_social["WallSep"] = glm_df_solo_social["WallSep"].astype(str).astype("category")

# %% [markdown]
# #### Solo df

# %%
glm_df_solo = pd.DataFrame()

for session_id, players in analysis_results.items():
    for player_id in players:
        
        # take each filtered_regressor array and fill the relevant df field for this player
        player_data = analysis_results[session_id][player_id]['solo']['regressors']
        choice = analysis_results[session_id][player_id]['solo']['dependent']['choice']
        df_player = pd.DataFrame(
                    {
                        "SessionID" : session_id,
                        "PlayerID" : player_id,
                        "GlmPlayerID" : session_id*2 + player_id,
                        "ChooseHigh" : choice,
                        "WallSep" : player_data['wall_sep'],
                        "FirstSeenWall" : player_data['first_seen'],
                        "D2H" : player_data['d2h'],
                        "D2L" : player_data['d2l']
                    }
        )

        # append this smaller dataframe to the the full dataframe
        glm_df_solo = pd.concat([glm_df_solo, df_player], ignore_index=True)


glm_df_solo["FirstSeenWall"] = glm_df_solo["FirstSeenWall"].astype(str).astype("category")
glm_df_solo["WallSep"] = glm_df_solo["WallSep"].astype(str).astype("category")

# %%
from contextlib import redirect_stdout


def generate_leave_one_out_dataframes(df):
    
    # randomise the order of the rows
    df_shuffle = df.sample(frac=1, random_state=17).reset_index(drop=True)

    # create lists to store the DataFrames
    dfs_with_row_removed = []
    dfs_with_removed_row = []

    # iterate through each row index in the DataFrame
    for i in range(len(df)):
        # create a DataFrame with one row removed
        df_without_row = df_shuffle.drop(index=i).reset_index(drop=True)
        dfs_with_row_removed.append(df_without_row)
        
        # create a DataFrame with only the removed row
        df_with_removed_row = df_shuffle.iloc[[i]].reset_index(drop=True)
        dfs_with_removed_row.append(df_with_removed_row)

    # Now you have two lists:
    # 1. dfs_with_row_removed: DataFrames with one row removed
    # 2. dfs_with_removed_row: DataFrames containing only the removed rows

    return dfs_with_row_removed, dfs_with_removed_row


def select_data_for_models(dfs_with_row_removed, dfs_with_removed_row, original_df_size, n=5, random_seed=None):

    if random_seed is not None:
        np.random.seed(random_seed)
    
    # randomly generate n integers between 0 and the length of the DataFrame, without replacement
    random_indices = np.random.choice(original_df_size, size=n, replace=False)

    # restrict the dfs_with_row_removed and dfs_with_removed_row lists to only the randomly selected indices
    dfs_with_row_removed_sampled = [dfs_with_row_removed[i] for i in random_indices]
    dfs_with_removed_row_sampled = [dfs_with_removed_row[i] for i in random_indices]

    print(dfs_with_removed_row_sampled)

    return dfs_with_row_removed_sampled, dfs_with_removed_row_sampled, random_indices

def fit_models(dfs_with_row_removed_sampled, model_formula):
    
    models = []
    with open(os.devnull, 'w') as fnull:
        with redirect_stdout(fnull):
            for i, df in enumerate(dfs_with_row_removed_sampled):
                model = Lmer(model_formula, data=df, family='binomial')
                model.fit()
                models.append(model)
                print(f"Model {i} fit with {len(df)} rows")
    
    return models

def calculate_predictions(models, original_df_size, dfs_with_removed_row_sampled, random_indices):
    
    predictions = np.full(len(dfs_with_removed_row_sampled), np.nan)
    predictions_maintained_index = np.full(original_df_size, np.nan)
    for i, model in enumerate(models):
        # get the row that was removed for this model
        removed_row = dfs_with_removed_row_sampled[i]
        
        # get the prediction for this row
        prediction = model.predict(removed_row, skip_data_checks=True, verify_predictions=False)
        
        # assign the prediction to the correct index in the predictions array
        predictions_maintained_index[random_indices[i]] = prediction[0]

        # also assign the prediction to the next index of a new array
        predictions[i] = prediction[0]

    return predictions, predictions_maintained_index

def calculate_likelihoods(df, predictions_maintained_index, random_indices):
    
    # calculate the metric for each prediction
    likelihoods = np.full(len(random_indices), np.nan)
    for i, idx in enumerate(random_indices):
        predicted_output = predictions_maintained_index[idx]
        true_output = df.iloc[idx]['ChooseHigh']
        likelihood = predicted_output**true_output * (1 - predicted_output)**(1 - true_output)
        likelihoods[i] = likelihood

    return likelihoods

def calculate_nll(likelihoods):
    # #### sum the logs of the likelihoods, and take the negative
    summed_log_likelihoods = np.sum(np.log(likelihoods)) 
    nll = -summed_log_likelihoods

    return nll

def save_cross_validation_results(name, model_formula, df, random_indices, models, predictions, nll):
    ''' Save the cross-validation results to a file. '''
    
    cross_validation_results = {
        "name": name,
        "model_formula": model_formula,
        "dataframe": df,
        "random_indices" : random_indices,
        # "models" : models,
        "predictions" : predictions,
        "nll" : nll
    }

    filename = f'./data/cross_validation_results_{name}.pickle'

    with open(filename, 'wb') as f:
        pickle.dump(cross_validation_results, f)

    print("Data saved to: ", filename)

# %%
def run_cross_validation(df, model_formula, name, n=50, save_results=False, random_seed=None):
    ''' Run leave-one-out cross-validation on the given dataframe and model formula.
        Returns the negative log-likelihood (NLL), fitted models, random indices, 
        predictions, and likelihoods.
        
        Arguments:
        df: DataFrame containing the data for cross-validation.
        model_formula: String representing the model formula for the GLM.
        name: String representing the name for saving the models.
        n: Number of random samples to select for cross-validation.
        save_models: Boolean indicating whether to save the models to file.
        
        Returns:
        nll: Negative log-likelihood of the model.
        models: List of fitted models.
        random_indices: List of random indices used for cross-validation.
        predictions: Array of predictions from the models.
        likelihoods: Array of likelihoods calculated from the predictions. '''
    
    n_rows = df.shape[0]

    # Step 1: Generate leave-one-out dataframes
    dfs_with_row_removed, dfs_with_removed_row = generate_leave_one_out_dataframes(df)

    # Step 2: Select data for models
    (dfs_with_row_removed_sampled,
     dfs_with_removed_row_sampled,
     random_indices) = select_data_for_models(dfs_with_row_removed, dfs_with_removed_row, n_rows, n, random_seed=random_seed)

    # Step 3: Fit models
    models = fit_models(dfs_with_row_removed_sampled, model_formula)

    # Step 4: Calculate predictions
    predictions, predictions_maintained_index = calculate_predictions(models, n_rows, dfs_with_removed_row_sampled, random_indices)

    # Step 5: Calculate likelihoods
    likelihoods = calculate_likelihoods(df, predictions_maintained_index, random_indices)

    # Step 6: Calculate NLL
    nll = calculate_nll(likelihoods)

    # Step 7: Save models to file (optional)
    if save_results:
        save_cross_validation_results(name, model_formula, df, random_indices, models, predictions, nll)
    
    return nll, models, random_indices, predictions, likelihoods

# %%
model_formula = 'ChooseHigh ~ 1 + D2H + D2L + FirstSeenWall + WallSep + (1|GlmPlayerID)'

# %%
(nll, models, random_indices,
  predictions, likelihoods) = run_cross_validation(glm_df_solo, model_formula,
                                                    "solo_randomintercepts_200", n=200,
                                                      save_results=True, random_seed=17)
# Out:
# [   SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         21         1           43         1.0     4.0           1.0  0.182902472  0.900229915,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          1         0            2         1.0     2.0           1.0  0.517459535  0.553905572,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         31         0           62         1.0     4.0           2.0  0.361550092  0.671577362,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         25         1           51         1.0     4.0           3.0  0.788965265  0.420592221,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          9         1           19         1.0     4.0           1.0  0.229056409  0.721192097,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          4         1            9         1.0     1.0           3.0  0.498156603  0.465206385,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         28         0           56         1.0     4.0           1.0  0.510056273  0.491535669,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         16         1           33         0.0     2.0           nan  0.657394279  0.010933173,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          7         0           14         1.0     4.0           3.0  0.334244002  0.903207489,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         22         1           45         0.0     4.0           1.0  0.850819953  0.078287639,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         29         1           59         1.0     1.0           2.0  0.358067928  0.656127936,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         31         1           63         1.0     2.0           1.0  0.383375309  0.524215536,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          4         0            8         1.0     2.0           nan  0.009582941  0.644694692,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         13         0           26         1.0     1.0           2.0  0.357938934  0.526346433,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         24         0           48         1.0     1.0           3.0  0.330699753  0.550812766,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H        D2L
# 0         30         0           60         1.0     2.0           3.0  0.902403699  0.7649278,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          3         1            7         1.0     4.0           3.0  0.637120008  0.667686375,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          4         0            8         0.0     4.0           1.0  0.688936823  0.480817948,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         19         0           38         1.0     2.0           2.0  0.338672454  0.452298885,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          9         0           18         1.0     1.0           3.0  0.480664516  0.463511137,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          9         0           18         1.0     2.0           2.0  0.512661586  0.499047546,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall         D2H          D2L
# 0         12         1           25         1.0     1.0           2.0  0.59977887  0.604750758,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         33         0           66         1.0     1.0           3.0  0.509164835  0.518726785,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         20         1           41         0.0     2.0           1.0  0.812367538  0.433013423,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         10         0           20         0.0     4.0           2.0  0.427444778  0.522173274,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         28         0           56         1.0     4.0           3.0  0.430339233  0.616319426,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          1         0            2         1.0     2.0           1.0  0.353919256  0.445176987,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          3         1            7         1.0     2.0           1.0  0.469722022  0.527272292,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         34         1           69         1.0     1.0           1.0  0.646294984  0.351348339,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          1         0            2         1.0     1.0           3.0  0.675913091  0.653617315,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         30         0           60         1.0     1.0           1.0  0.502163301  0.493588337,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H         D2L
# 0          6         0           12         1.0     2.0           1.0  0.483197347  0.47346975,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          1         1            3         1.0     1.0           3.0  0.570611471  0.646844269,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         21         0           42         1.0     1.0           1.0  0.545047424  0.282213831,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         20         0           40         1.0     1.0           3.0  0.370913434  0.446319151,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         18         1           37         1.0     4.0           1.0  0.561741202  0.374109622,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         18         1           37         1.0     2.0           3.0  0.292941072  0.559316465,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         13         1           27         1.0     4.0           2.0  0.287042862  0.637745291,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          3         0            6         1.0     2.0           1.0  0.365675492  0.461356437,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          1         1            3         1.0     2.0           1.0  0.336442027  0.359772328,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         29         1           59         1.0     1.0           3.0  0.836716611  0.923167506,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         22         0           44         0.0     4.0           2.0  0.768976318  0.271343391,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          1         1            3         1.0     2.0           2.0  0.376069627  0.516391987,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         30         1           61         1.0     1.0           1.0  0.425930243  0.366570058,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         29         1           59         1.0     2.0           1.0  0.907935397  0.645308113,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         33         0           66         1.0     1.0           2.0  0.445046723  0.563989629,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall         D2H         D2L
# 0         16         0           32         1.0     2.0           1.0  0.44522322  0.47898447,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H         D2L
# 0         34         0           68         1.0     2.0           1.0  0.372690055  0.55186089,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         28         0           56         1.0     1.0           1.0  0.261905181  0.319159636,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         31         0           62         1.0     1.0           1.0  0.656385665  0.510975631,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         16         0           32         0.0     2.0           2.0  0.398089073  0.267020357,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         28         1           57         1.0     4.0           3.0  0.382018737  0.855359719,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         31         0           62         1.0     1.0           3.0  0.611190402  0.576488939,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         29         1           59         1.0     1.0           1.0  0.679290803  0.383165367,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall         D2H          D2L
# 0         18         0           36         1.0     2.0           3.0  0.50461562  0.516026339,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         31         1           63         1.0     2.0           1.0  0.389562057  0.466738859,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          2         1            5         1.0     4.0           1.0  0.599458997  0.388562272,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         19         1           39         1.0     1.0           3.0  0.906957846  0.845746988,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall         D2H          D2L
# 0         30         1           61         1.0     1.0           3.0  0.44716366  0.517684004,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          8         0           16         1.0     1.0           2.0  0.583882165  0.543408898,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          7         0           14         1.0     1.0           3.0  0.626260192  0.359241464,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         21         1           43         0.0     4.0           2.0  0.276434898  0.647957373,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         14         1           29         0.0     4.0           2.0  0.459646178  0.464831519,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         11         0           22         1.0     1.0           1.0  0.588524714  0.342264193,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          4         1            9         0.0     4.0           2.0  0.408417918  0.583289519,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          0         1            1         1.0     4.0           2.0  0.428824781  0.509843131,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          4         1            9         0.0     2.0           2.0  0.490345797  0.651693433,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H         D2L
# 0         19         0           38         1.0     1.0           2.0  0.462724046  0.44928568,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         34         1           69         1.0     1.0           2.0  0.364831342  0.658816686,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         21         0           42         1.0     1.0           2.0  0.778250154  0.851290399,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          1         0            2         0.0     4.0           2.0  0.352839846  0.578739376,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall         D2H          D2L
# 0         30         0           60         1.0     1.0           3.0  0.90235172  0.764927699,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H         D2L
# 0          6         1           13         1.0     2.0           1.0  0.648257257  0.40290168,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall         D2H          D2L
# 0         15         1           31         1.0     1.0           3.0  0.68735515  0.881372421,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         26         0           52         1.0     2.0           3.0  0.660668525  0.014225271,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H         D2L
# 0         12         1           25         0.0     4.0           2.0  0.471159099  0.45758239,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         14         0           28         1.0     1.0           2.0  0.461980731  0.461980731,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         17         0           34         1.0     2.0           1.0  0.763499338  0.212258093,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         18         0           36         1.0     4.0           1.0  0.361716881  0.566588602,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         18         0           36         1.0     4.0           2.0  0.502156305  0.430157323,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         14         0           28         0.0     2.0           2.0  0.388447151  0.505464963,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H         D2L
# 0          3         0            6         1.0     2.0           3.0  0.478619939  0.42484469,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          5         0           10         0.0     4.0           2.0  0.572730898  0.361232862,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         17         0           34         1.0     1.0           3.0  0.785454224  0.889499284,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         28         0           56         1.0     1.0           3.0  0.383061041  0.450342948,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          9         0           18         0.0     4.0           2.0  0.571130321  0.423455746,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall         D2H          D2L
# 0         13         0           26         1.0     4.0           1.0  0.38931499  0.534886821,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         14         1           29         0.0     2.0           2.0  0.463530002  0.478118258,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          2         0            4         0.0     1.0           nan  0.410846675  0.059294284,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         31         1           63         1.0     1.0           3.0  0.455775682  0.441406788,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          8         1           17         1.0     1.0           1.0  0.413274232  0.261421214,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         32         0           64         1.0     4.0           1.0  0.888450658  0.080305462,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         16         0           32         1.0     1.0           3.0  0.573024858  0.512042813,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         20         0           40         1.0     2.0           1.0  0.414166389  0.587780823,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         30         0           60         1.0     4.0           1.0  0.466822126  0.468959548,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         30         0           60         1.0     1.0           3.0  0.902351726  0.902403711,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         29         1           59         1.0     2.0           1.0  0.837606313  0.318521457,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         25         1           51         1.0     1.0           3.0  0.511276676  0.765075662,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         11         1           23         1.0     2.0           2.0  0.330122874  0.483164257,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall         D2H          D2L
# 0         32         1           65         1.0     1.0           1.0  0.64496255  0.486310733,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          1         1            3         1.0     4.0           1.0  0.365691771  0.571781395,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         23         1           47         1.0     1.0           3.0  0.896632895  0.886951328,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         25         1           51         1.0     2.0           1.0  0.211825238  0.441518655,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         16         1           33         1.0     2.0           1.0  0.582581776  0.815519318,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         14         0           28         1.0     4.0           2.0  0.669163423  0.390218295,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         24         1           49         1.0     1.0           3.0  0.888697006  0.846253055,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall         D2H         D2L
# 0         29         0           58         1.0     1.0           2.0  0.39853899  0.41252956,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall         D2H          D2L
# 0         19         1           39         1.0     4.0           2.0  0.36852347  0.792687071,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          8         0           16         1.0     1.0           1.0  0.300693308  0.497191933,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         18         0           36         1.0     1.0           2.0  0.506064474  0.512230236,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         17         1           35         1.0     4.0           1.0  0.652500787  0.354533434,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         12         0           24         1.0     1.0           2.0  0.614558853  0.660762179,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H         D2L
# 0         25         0           50         1.0     1.0           1.0  0.543642215  0.48037806,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         25         0           50         1.0     1.0           3.0  0.344255937  0.385098536,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         28         0           56         0.0     1.0           1.0  0.344997978  0.468648086,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          1         0            2         1.0     2.0           2.0  0.504507409  0.421012521,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         21         1           43         0.0     4.0           2.0  0.320616381  0.655917456,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         31         1           63         1.0     1.0           3.0  0.514626518  0.533418163,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         29         1           59         1.0     1.0           2.0  0.665754897  0.845649592,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          0         0            0         1.0     4.0           3.0  0.510946074  0.765097742,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         29         0           58         1.0     1.0           1.0  0.499679669  0.465481891,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H         D2L
# 0         15         1           31         1.0     4.0           3.0  0.852589637  0.32640215,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          5         0           10         1.0     1.0           1.0  0.522843837  0.548548171,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         21         0           42         0.0     4.0           2.0  0.081472701  0.843247531,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         30         0           60         1.0     4.0           2.0  0.179665445  0.902351726,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         31         0           62         1.0     4.0           2.0  0.369061569  0.639883051,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         24         0           48         1.0     1.0           1.0  0.913229885  0.860603118,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         21         1           43         1.0     2.0           1.0  0.569844337  0.532810363,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         29         1           59         1.0     2.0           3.0  0.662421448  0.923219864,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         25         0           50         1.0     4.0           2.0  0.537639425  0.386738118,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         24         0           48         1.0     1.0           1.0  0.380800454  0.324123827,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         25         1           51         1.0     2.0           2.0  0.278503699  0.643155569,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         30         0           60         1.0     4.0           2.0  0.179987491  0.902519795,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         32         0           64         1.0     2.0           1.0  0.867234766  0.673976088,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         25         0           50         1.0     4.0           2.0  0.499934125  0.427883767,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall         D2H          D2L
# 0         33         1           67         1.0     4.0           1.0  0.69865742  0.255533598,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         20         1           41         1.0     1.0           2.0  0.288942868  0.439200329,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          3         0            6         1.0     2.0           3.0  0.375115196  0.456180771,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          4         0            8         1.0     4.0           3.0  0.724750136  0.424338633,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         19         1           39         1.0     1.0           1.0  0.649641255  0.362231821,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         32         1           65         1.0     1.0           3.0  0.522813822  0.579976657,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall         D2H          D2L
# 0          4         1            9         1.0     2.0           3.0  0.80098459  0.843523706,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H         D2L
# 0         28         0           56         0.0     4.0           2.0  0.532465932  0.39186801,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         23         0           46         0.0     2.0           3.0  0.775777176  0.220620726,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         11         1           23         1.0     1.0           3.0  0.475107071  0.402474161,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         13         0           26         1.0     1.0           2.0  0.574196299  0.589946536,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         27         1           55         1.0     2.0           1.0  0.865398405  0.581271014,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          9         0           18         1.0     4.0           2.0  0.372830902  0.555708477,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         10         0           20         1.0     1.0           1.0  0.553067984  0.461648099,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         22         1           45         1.0     1.0           2.0  0.342793579  0.459020431,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         15         0           30         1.0     2.0           1.0  0.519446022  0.449169608,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         25         1           51         1.0     2.0           3.0  0.530519282  0.258153344,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall         D2H          D2L
# 0          7         0           14         1.0     4.0           1.0  0.73002385  0.376455394,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H         D2L
# 0         32         0           64         1.0     1.0           3.0  0.233451562  0.54793311,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         20         1           41         1.0     4.0           1.0  0.470364432  0.460879917,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         28         0           56         1.0     1.0           3.0  0.387412597  0.450302341,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         22         0           44         1.0     1.0           1.0  0.336282456  0.288540797,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         33         0           66         1.0     4.0           2.0  0.434842948  0.489434815,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall         D2H          D2L
# 0         21         1           43         1.0     4.0           3.0  0.26091809  0.855381619,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H         D2L
# 0         28         1           57         1.0     4.0           nan  0.038618474  0.96257889,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         21         1           43         1.0     1.0           2.0  0.536415825  0.459659433,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         27         0           54         1.0     2.0           3.0  0.683350354  0.943717859,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         10         1           21         1.0     2.0           1.0  0.394626016  0.470407682,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         28         0           56         1.0     1.0           2.0  0.370303194  0.164938128,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          5         0           10         1.0     2.0           1.0  0.518450411  0.249921598,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          8         0           16         1.0     4.0           1.0  0.341345363  0.583047011,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         25         0           50         1.0     2.0           3.0  0.492813772  0.475268777,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          0         1            1         1.0     1.0           3.0  0.479324954  0.369580678,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H         D2L
# 0         16         1           33         1.0     4.0           2.0  0.439871338  0.53549306,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         23         1           47         1.0     1.0           3.0  0.581103837  0.331566521,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          5         0           10         1.0     1.0           1.0  0.680939914  0.680647503,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          3         0            6         0.0     2.0           2.0  0.476626294  0.505198189,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          9         1           19         1.0     1.0           1.0  0.280548924  0.444300579,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         26         1           53         1.0     4.0           1.0  0.599641447  0.364539434,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         30         0           60         1.0     4.0           1.0  0.902351787  0.179665354,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         26         1           53         1.0     1.0           3.0  0.680331732  0.549747315,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         26         0           52         1.0     2.0           nan  0.034667577  0.684219636,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         11         0           22         1.0     1.0           2.0  0.544726356  0.522973461,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         32         0           64         1.0     4.0           1.0  0.808973683  0.289104278,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         20         0           40         1.0     2.0           1.0  0.407838059  0.258469945,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         31         0           62         1.0     1.0           1.0  0.390557915  0.581940159,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         24         0           48         1.0     4.0           1.0  0.593972289  0.635901124,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         34         0           68         1.0     4.0           3.0  0.732320506  0.533619145,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         25         1           51         1.0     4.0           2.0  0.666226755  0.497437983,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         31         1           63         1.0     4.0           1.0  0.496852145  0.439493439,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          7         1           15         1.0     4.0           1.0  0.784598039  0.209832169,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         18         0           36         1.0     4.0           2.0  0.454010653  0.470010953,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          5         0           10         0.0     1.0           1.0  0.953107429  0.890751998,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         27         1           55         1.0     1.0           3.0  0.635668917  0.395424637,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         26         0           52         1.0     4.0           2.0  0.772381879  0.476784869,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         22         0           44         1.0     2.0           1.0  0.449933277  0.633762366,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          1         1            3         1.0     2.0           1.0  0.347708473  0.398130334,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0          0         0            0         0.0     2.0           2.0  0.471214649  0.510139255,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         20         1           41         1.0     1.0           1.0  0.512331985  0.648438391,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         29         1           59         1.0     1.0           3.0  0.349916423  0.651696182,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         19         1           39         1.0     1.0           1.0  0.623300778  0.500389747,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         11         1           23         1.0     4.0           1.0  0.367691594  0.579945088,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         29         0           58         1.0     1.0           3.0  0.893835964  0.835623984,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         24         0           48         1.0     4.0           3.0  0.405596482  0.856425768,    SessionID  PlayerID  GlmPlayerID  ChooseHigh WallSep FirstSeenWall          D2H          D2L
# 0         32         1           65         1.0     1.0           3.0  0.844168918  0.793592347]
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# ...
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# d:\Users\Tom\miniconda3\envs\octagon_analysis\Lib\site-packages\pymer4\models\Lmer.py:733: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ran_vars = ran_vars.applymap(
# Data saved to:  ./data/cross_validation_results_solo_randomintercepts_200.pickle

# %%
random_indices, models, predictions, likelihoods, nll
# Out:
# (array([ 376, 3187, 3099, 2178, 1094,  680, 3275, 2389, 3185, 1418,  248,
#         1000, 3539, 3516, 2481, 2030,  767, 2264,  184, 1238, 2989, 1208,
#         3695, 3177, 1074, 4280,  794, 1120, 3079, 2630, 3744, 3434, 2254,
#         4387, 3135, 1719, 3800, 3824, 3219, 3791, 2652, 2397, 1051,   39,
#         3016, 4548,   69, 4470, 3915, 3890, 3223,  808, 1028, 2722, 2698,
#         3523, 4170, 3501,  265, 2691, 2559, 1401, 2257, 4377,  805,   65,
#         3278, 2443,  684, 1565, 1965, 2633, 2791, 3853, 2575, 2715, 4477,
#         2611, 1442, 1882,  243,  756,  981, 2747,  394, 4151, 1908, 1339,
#         2203, 3486,  936, 3745, 2029, 4273, 2689,  676,  606, 3239,  749,
#         1264,   18, 2199,  686, 1687, 4164, 1662, 2503, 3527, 2265, 3195,
#         1482,  179,  866, 1995, 3034, 2111,  912, 4072, 1073, 3851, 1817,
#         2384, 2857,    3,  822, 4035, 2579,  780, 1335, 1907,   29, 3491,
#         1083, 3119,   72, 3794, 1985, 2196, 1691, 1972,  644, 4317, 2960,
#         1718, 3156, 3966, 3797, 1706, 1629, 3652, 1650, 2110, 4400, 3863,
#         2637, 3502,  630, 3777, 4135, 1808, 2390, 2002,  619, 3796, 2946,
#         3829, 4600, 3843, 1739, 4141, 2788,  919, 3240,   44, 3940, 1825,
#         1119,  132,  233, 1168, 2349, 4416, 3390,  411, 1878,  563, 4594,
#         1220,  549,  720, 3872,  729, 4469, 2063, 2104, 2927, 4499, 4118,
#         1095, 2482], dtype=int32),
#  [pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial),
#   pymer4.models.Lmer(fitted = True, formula = ChooseHigh~1+D2H+D2L+FirstSeenWall+WallSep+(1|GlmPlayerID), family = binomial)],
#  array([0.98838478, 0.9937769 , 0.80599962, 0.98170433, 0.77393057,
#         0.90466255, 0.87922375, 0.22136175, 0.97016191, 0.92836063,
#         0.98214344, 0.99234181, 0.21155227, 0.97266559, 0.95609202,
#         0.96062455, 0.96419883, 0.76500168, 0.73096394, 0.99531482,
#         0.90602394, 0.85584173, 0.99652606, 0.85525763, 0.36541942,
#         0.83279693, 0.99242453, 0.98278618, 0.99671792, 0.99609983,
#         0.9906964 , 0.97803217, 0.97230235, 0.93238703, 0.97600399,
#         0.97001606, 0.97505098, 0.7872214 , 0.96678645, 0.92824083,
#         0.9983957 , 0.47889967, 0.52908253, 0.97115055, 0.99451374,
#         0.97916433, 0.98987862, 0.99329443, 0.95279999, 0.99232802,
#         0.81217921, 0.98473204, 0.98622228, 0.9966995 , 0.99334098,
#         0.99078514, 0.99169148, 0.9957574 , 0.95829785, 0.8872521 ,
#         0.94503494, 0.69848347, 0.86040667, 0.98158341, 0.36003545,
#         0.71254409, 0.44684358, 0.88491499, 0.98348437, 0.79215746,
#         0.93235457, 0.98700786, 0.9888621 , 0.99207297, 0.4807794 ,
#         0.565147  , 0.78495583, 0.8145642 , 0.99733463, 0.92321757,
#         0.62555765, 0.90966308, 0.36434762, 0.98037949, 0.92211274,
#         0.90936533, 0.99384767, 0.88787674, 0.54432664, 0.99211663,
#         0.99583617, 0.95531873, 0.99238579, 0.97848813, 0.96379839,
#         0.99153479, 0.98567475, 0.99871468, 0.87327208, 0.9984379 ,
#         0.95257738, 0.97661349, 0.9963384 , 0.99197163, 0.37184062,
#         0.99714076, 0.88439639, 0.91710855, 0.99354165, 0.98392848,
#         0.8410399 , 0.79411165, 0.99764558, 0.99386637, 0.97054542,
#         0.85567847, 0.69528594, 0.99377464, 0.98704099, 0.90170678,
#         0.99310084, 0.82615001, 0.98529668, 0.68622092, 0.88577681,
#         0.78844668, 0.98763393, 0.95877671, 0.99574224, 0.82317207,
#         0.95932346, 0.96538979, 0.88580185, 0.99431891, 0.8464047 ,
#         0.93400333, 0.60394732, 0.92427386, 0.49029268, 0.993314  ,
#         0.99758965, 0.88445999, 0.23883034, 0.23487061, 0.99137143,
#         0.97290236, 0.94452162, 0.9142538 , 0.96233388, 0.92168447,
#         0.99268299, 0.98024173, 0.90873572, 0.99640403, 0.86459126,
#         0.9218256 , 0.9882746 , 0.90638702, 0.9674929 , 0.88735413,
#         0.77026765, 0.99090714, 0.99328771, 0.3866238 , 0.89329757,
#         0.98072723, 0.98378385, 0.97830804, 0.71777325, 0.90515648,
#         0.98880501, 0.66462153, 0.84144291, 0.96834066, 0.87810831,
#         0.9882949 , 0.45846628, 0.84680305, 0.97804203, 0.94169361,
#         0.9951358 , 0.93166909, 0.97278135, 0.90885901, 0.9864987 ,
#         0.94612785, 0.93471987, 0.99400019, 0.93984034, 0.28112869,
#         0.98644244, 0.93534817, 0.43269149, 0.97711586, 0.99755067,
#         0.99576255, 0.99259106, 0.99295508, 0.93309948, 0.99836394]),
#  array([0.98838478, 0.0062231 , 0.80599962, 0.01829567, 0.77393057,
#         0.90466255, 0.87922375, 0.22136175, 0.97016191, 0.92836063,
#         0.98214344, 0.00765819, 0.21155227, 0.97266559, 0.95609202,
#         0.96062455, 0.96419883, 0.76500168, 0.73096394, 0.99531482,
#         0.90602394, 0.85584173, 0.99652606, 0.85525763, 0.36541942,
#         0.83279693, 0.99242453, 0.98278618, 0.99671792, 0.99609983,
#         0.9906964 , 0.97803217, 0.97230235, 0.93238703, 0.97600399,
#         0.97001606, 0.97505098, 0.7872214 , 0.96678645, 0.92824083,
#         0.9983957 , 0.47889967, 0.52908253, 0.97115055, 0.99451374,
#         0.97916433, 0.01012138, 0.99329443, 0.95279999, 0.99232802,
#         0.81217921, 0.98473204, 0.98622228, 0.9966995 , 0.99334098,
#         0.99078514, 0.99169148, 0.9957574 , 0.95829785, 0.8872521 ,
#         0.94503494, 0.69848347, 0.86040667, 0.98158341, 0.36003545,
#         0.71254409, 0.44684358, 0.11508501, 0.98348437, 0.79215746,
#         0.93235457, 0.98700786, 0.9888621 , 0.99207297, 0.4807794 ,
#         0.565147  , 0.78495583, 0.8145642 , 0.99733463, 0.92321757,
#         0.62555765, 0.90966308, 0.63565238, 0.98037949, 0.92211274,
#         0.90936533, 0.99384767, 0.11212326, 0.54432664, 0.99211663,
#         0.99583617, 0.04468127, 0.99238579, 0.97848813, 0.96379839,
#         0.99153479, 0.98567475, 0.99871468, 0.87327208, 0.9984379 ,
#         0.95257738, 0.97661349, 0.9963384 , 0.99197163, 0.37184062,
#         0.00285924, 0.11560361, 0.91710855, 0.99354165, 0.98392848,
#         0.8410399 , 0.79411165, 0.99764558, 0.99386637, 0.97054542,
#         0.85567847, 0.69528594, 0.99377464, 0.98704099, 0.09829322,
#         0.99310084, 0.82615001, 0.98529668, 0.68622092, 0.11422319,
#         0.78844668, 0.98763393, 0.95877671, 0.00425776, 0.82317207,
#         0.95932346, 0.96538979, 0.88580185, 0.99431891, 0.8464047 ,
#         0.93400333, 0.60394732, 0.92427386, 0.50970732, 0.993314  ,
#         0.99758965, 0.88445999, 0.23883034, 0.23487061, 0.00862857,
#         0.97290236, 0.94452162, 0.9142538 , 0.96233388, 0.92168447,
#         0.99268299, 0.98024173, 0.90873572, 0.99640403, 0.86459126,
#         0.9218256 , 0.9882746 , 0.90638702, 0.9674929 , 0.88735413,
#         0.77026765, 0.99090714, 0.00671229, 0.3866238 , 0.10670243,
#         0.01927277, 0.98378385, 0.97830804, 0.71777325, 0.90515648,
#         0.98880501, 0.66462153, 0.15855709, 0.03165934, 0.87810831,
#         0.9882949 , 0.45846628, 0.84680305, 0.97804203, 0.94169361,
#         0.9951358 , 0.93166909, 0.97278135, 0.90885901, 0.9864987 ,
#         0.94612785, 0.93471987, 0.99400019, 0.93984034, 0.28112869,
#         0.98644244, 0.93534817, 0.43269149, 0.02288414, 0.00244933,
#         0.99576255, 0.99259106, 0.99295508, 0.93309948, 0.00163606]),
#  np.float64(111.97705578634833))

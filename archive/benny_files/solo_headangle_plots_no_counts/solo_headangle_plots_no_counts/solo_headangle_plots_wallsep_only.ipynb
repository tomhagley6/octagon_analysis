# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
main_copy_dir = os.path.join(parent_dir, "main_copy")
octagon_analysis = os.path.join(parent_dir, "octagon_analysis")
sys.path.append(main_copy_dir)
sys.path.append(octagon_analysis)

print("Added paths to sys.path:", main_copy_dir, octagon_analysis)
# Out:
# Added paths to sys.path: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy /Users/benny/Desktop/MSc/Project/Git/repos/octagon_analysis

# %%
print(sys.executable)
# Out:
# /usr/local/bin/python3

# %%
#imports
# %load_ext autoreload
# %autoreload 2
import scipy
import parse_data.prepare_data as prepare_data
import numpy as np
import pandas as pd
from parse_data import preprocess
import matplotlib as mpl
import matplotlib.pyplot as plt
import globals
import plotting.plot_trajectory as plot_trajectory
import plotting.plot_octagon as plot_octagon
import data_extraction.extract_trial as extract_trial
import data_extraction.trial_list_filters as trial_list_filters
import math
import trajectory_analysis.trajectory_vectors as trajectory_vectors
import trajectory_analysis.trajectory_headangle as trajectory_headangle
from IPython.display import Image, display
import data_extraction.get_indices as get_indices
import prominent_direction_functions as prominent_direction_functions
import flip_rotate_headangle_functions
import headangle_analysis_plotting_functions
import headangle_bin_assignment_new
import analysis.wall_visibility_and_choice as wall_visibility_and_choice
import calculate_probabilities_functions
import filtering_functions
import plot_headangle_vectors_colour_map
import fast_track_flip_and_rotate
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import glob
data_folder = '/Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev'
json_filenames_all_social = glob.glob(r'json_social/*.json')
json_filenames_all_solo = glob.glob(r'json_solos/*.json')

# %%
json_filenames = json_filenames_all_solo
df, trial_lists = prepare_data.prepare_data(data_folder, json_filenames, combine=False)
print(len(trial_lists))
trial_lists = [trial_lists[i] + trial_lists[i+1] for i in range(0, len(trial_lists), 2)]
# Out:
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-20_17-36-54_ChristopherFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2025-01-15_15-12-39_MarcoFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-19_15-51-33_YeungSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-12_15-44-54_FrancescaSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-13_14-37-20_RyanSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-12_15-11-45_SenFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-20_15-39-49_VinceSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-19_14-18-18_AmyFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-12_15-45-35_SenSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-12_13-50-23_KhadijaSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-13_15-21-50_HoiFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-03_15-53-11_EstherSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-09-13_11-23-37_YansuFirstSolo.json
# Data is from period before 2024-09-13 00:00:00
# Running dataframe through playerinfo_playerposition_conversion.
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-13_15-22-20_YichuanFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-20_15-10-17_VinceFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-03_15-19-51_EstherFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-10_15-12-18_RyanFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-12_13-18-59_WendyFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-10-17_14-51-22_AbigailSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-09-13_11-53-56_JerrySecondSolo.json
# Data is from period before 2024-09-13 00:00:00
# Running dataframe through playerinfo_playerposition_conversion.
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-09-27_14-14-42_EmilyFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-12_13-50-20_WendySecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-10_14-45-09_TasSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2025-01-15_15-46-04_MarcoSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-10-17_14-20-50_AbigailFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-13_15-51-39_YichuanSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-03_14-52-30_NicoleSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-20_14-41-56_RahulSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-10-17_14-20-28_ShamirFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2025-01-15_15-47-11_YixuanSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-19_15-15-53_SophiaFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-03_14-20-13_PaulFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-10_15-11-46_RoseFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-20_15-40-08_SunnySecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-09-27_14-14-31_SaraFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-09-27_14-45-46_EmilySecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-12_13-19-22_KhadijaFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-12_15-13-34_FrancescaFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-19_15-47-53_SophiaSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-20_14-12-33_RahulFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-10-17_14-50-03_ShamirSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-03_15-52-57_BowinSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-13_14-12-43_NasiaFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-09-13_11-53-34_YansuSecondSolo.json
# Data is from period before 2024-09-13 00:00:00
# Running dataframe through playerinfo_playerposition_conversion.
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-10-17_17-12-29_ElsaSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-19_15-22-13_YeungFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-19_15-51-58_JingjingSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-13_14-37-06_NasiaSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-10_14-45-41_TaqwaSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-10_15-42-27_RyanSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-13_15-51-16_HoiSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-10_14-12-58_TasFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-19_14-18-44_XinyuanFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-03_14-52-05_PaulSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-20_18-06-44_ChristopherSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-10-17_16-35-45_ElsaFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-20_15-10-00_SunnyFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-19_14-44-31_XinyuanSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-20_14-12-06_JasonFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-10-17_16-36-0_ZimoFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-10_15-41-53_RoseSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-09-27_14-45-55_SaraSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-10-17_17-11-46_ZimoSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-19_15-14-19_HocineFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-03_15-20-09_BowinFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-13_14-12-41_RyanFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-20_14-42-16_JasonSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-03_14-19-21_NicoleFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-19_15-20-18_JingjingFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-09-13_11-23-50_JerryFirstSolo.json
# Data is from period before 2024-09-13 00:00:00
# Running dataframe through playerinfo_playerposition_conversion.
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-12-10_14-13-47_TaqwaFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2025-01-15_15-12-13_YixuanFirstSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-19_15-47-29_HocineSecondSolo.json
# Loading complete.
# Preprocessing complete.
# filepath: /Users/benny/Desktop/MSc/Project/Git/repos/main_copy/benny_dev/json_solos/2024-11-19_14-44-00_AmySecondSolo.json
# Loading complete.
# Preprocessing complete.
# 74

# %%
updated_lists_wallsep_solo=[]
for trial_list in range(len(trial_lists)):
    updated_list = fast_track_flip_and_rotate.process_and_update_trials_both_players_fast(trial_lists[trial_list])
    updated_lists_wallsep_solo.append(updated_list)

# %% [markdown]
# Computing nominator, denominator and probabilities for plots for:
# 45°,90°,180°
# 1) LW visible first
# 2) HW visible first
# 3) both walls visible at slice onset

# %%
fov=110 #set
wall_index=0 #for p(high)
player_id=0

#change
wall_sep=None
both=False #set to true for both walls visible at slice onset

updated=True #needed for head angle bins
inferred_choice=False #for solos

# %%
def apply_filters(trial_list, updated_list, wall_sep):
    """Apply filtering steps while keeping both lists aligned."""
    trial_indices = get_indices.get_trials_trialtype(trial_list, trial_type=globals.HIGH_LOW)
    trial_list = [trial_list[i] for i in trial_indices]
    updated_list = [updated_list[i] for i in trial_indices]  # Ensure alignment

    if wall_sep is not None:
        trial_indices = get_indices.get_trials_with_wall_sep(trial_list, wall_sep=wall_sep)
        trial_list = [trial_list[i] for i in trial_indices]
        updated_list = [updated_list[i] for i in trial_indices]  # Keep them aligned!

    return trial_list, updated_list

# %%
filtered_trials_nominator = {}
updated_trials_nominator = {}

for session_id, (trial_list, updated_list) in enumerate(zip(trial_lists, updated_lists_wallsep_solo)):
    trial_list, updated_list = apply_filters(trial_list, updated_list, wall_sep)

    # Initialize dictionaries properly
    filtered_trials_nominator[session_id] = {'by_player': {}}
    updated_trials_nominator[session_id] = {'by_player': {}}

    print(f"Session: {session_id}, Player: {player_id}, Trial List Length: {len(trial_list)}, Updated List Length: {len(updated_list)}")

    trial_list_filtered, updated_list_filtered, _ = filtering_functions.headangle_and_choice_nominator(trial_list, updated_list, player_id, inferred_choice, wall_index, head_angle_bin=None, updated=updated)


    filtered_trials_nominator[session_id]['by_player'][player_id] = trial_list_filtered
    updated_trials_nominator[session_id]['by_player'][player_id] = updated_list_filtered

    print(f"Completed: Session {session_id}")
# Out:
# Session: 0, Player: 0, Trial List Length: 64, Updated List Length: 64
# Completed: Session 0
# Session: 1, Player: 0, Trial List Length: 81, Updated List Length: 81
# Completed: Session 1
# Session: 2, Player: 0, Trial List Length: 54, Updated List Length: 54
# Completed: Session 2
# Session: 3, Player: 0, Trial List Length: 50, Updated List Length: 50
# Completed: Session 3
# Session: 4, Player: 0, Trial List Length: 76, Updated List Length: 76
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Completed: Session 4
# Session: 5, Player: 0, Trial List Length: 45, Updated List Length: 45
# Completed: Session 5
# Session: 6, Player: 0, Trial List Length: 48, Updated List Length: 48
# Completed: Session 6
# Session: 7, Player: 0, Trial List Length: 44, Updated List Length: 44
# Completed: Session 7
# Session: 8, Player: 0, Trial List Length: 47, Updated List Length: 47
# Completed: Session 8
# Session: 9, Player: 0, Trial List Length: 55, Updated List Length: 55
# Completed: Session 9
# Session: 10, Player: 0, Trial List Length: 56, Updated List Length: 56
# Completed: Session 10
# Session: 11, Player: 0, Trial List Length: 62, Updated List Length: 62
# Completed: Session 11
# Session: 12, Player: 0, Trial List Length: 52, Updated List Length: 52
# Completed: Session 12
# Session: 13, Player: 0, Trial List Length: 42, Updated List Length: 42
# Completed: Session 13
# Session: 14, Player: 0, Trial List Length: 45, Updated List Length: 45
# Completed: Session 14
# Session: 15, Player: 0, Trial List Length: 47, Updated List Length: 47
# Completed: Session 15
# Session: 16, Player: 0, Trial List Length: 47, Updated List Length: 47
# Completed: Session 16
# Session: 17, Player: 0, Trial List Length: 56, Updated List Length: 56
# Completed: Session 17
# Session: 18, Player: 0, Trial List Length: 64, Updated List Length: 64
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Completed: Session 18
# Session: 19, Player: 0, Trial List Length: 45, Updated List Length: 45
# Completed: Session 19
# Session: 20, Player: 0, Trial List Length: 52, Updated List Length: 52
# Completed: Session 20
# Session: 21, Player: 0, Trial List Length: 50, Updated List Length: 50
# Completed: Session 21
# Session: 22, Player: 0, Trial List Length: 67, Updated List Length: 67
# Completed: Session 22
# Session: 23, Player: 0, Trial List Length: 47, Updated List Length: 47
# Completed: Session 23
# Session: 24, Player: 0, Trial List Length: 51, Updated List Length: 51
# Completed: Session 24
# Session: 25, Player: 0, Trial List Length: 49, Updated List Length: 49
# Completed: Session 25
# Session: 26, Player: 0, Trial List Length: 47, Updated List Length: 47
# Completed: Session 26
# Session: 27, Player: 0, Trial List Length: 47, Updated List Length: 47
# Completed: Session 27
# Session: 28, Player: 0, Trial List Length: 46, Updated List Length: 46
# Completed: Session 28
# Session: 29, Player: 0, Trial List Length: 29, Updated List Length: 29
# Completed: Session 29
# Session: 30, Player: 0, Trial List Length: 51, Updated List Length: 51
# Completed: Session 30
# Session: 31, Player: 0, Trial List Length: 58, Updated List Length: 58
# Completed: Session 31
# Session: 32, Player: 0, Trial List Length: 42, Updated List Length: 42
# Completed: Session 32
# Session: 33, Player: 0, Trial List Length: 52, Updated List Length: 52
# Completed: Session 33
# Session: 34, Player: 0, Trial List Length: 60, Updated List Length: 60
# Completed: Session 34
# Session: 35, Player: 0, Trial List Length: 55, Updated List Length: 55
# Completed: Session 35
# Session: 36, Player: 0, Trial List Length: 49, Updated List Length: 49
# Completed: Session 36

# %%
filtered_trials_denominator = {}
updated_trials_denominator = {}

for session_id, (trial_list, updated_list) in enumerate(zip(trial_lists, updated_lists_wallsep_solo)):
    trial_list, updated_list = apply_filters(trial_list, updated_list, wall_sep)

    # Initialize dictionaries properly
    filtered_trials_denominator[session_id] = {'by_player': {}}
    updated_trials_denominator[session_id] = {'by_player': {}}

    print(f"Session: {session_id}, Player: {player_id}, Trial List Length: {len(trial_list)}, Updated List Length: {len(updated_list)}")

    trial_list_filtered, updated_list_filtered, _ = filtering_functions.headangle_and_choice_denominator(trial_list, updated_list, player_id, inferred_choice, head_angle_bin=None, updated=updated)
    
    filtered_trials_denominator[session_id]['by_player'][player_id] = trial_list_filtered
    updated_trials_denominator[session_id]['by_player'][player_id] = updated_list_filtered

    print(f"Completed: Session {session_id}")
# Out:
# Session: 0, Player: 0, Trial List Length: 64, Updated List Length: 64
# Completed: Session 0
# Session: 1, Player: 0, Trial List Length: 81, Updated List Length: 81
# Completed: Session 1
# Session: 2, Player: 0, Trial List Length: 54, Updated List Length: 54
# Completed: Session 2
# Session: 3, Player: 0, Trial List Length: 50, Updated List Length: 50
# Completed: Session 3
# Session: 4, Player: 0, Trial List Length: 76, Updated List Length: 76
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Completed: Session 4
# Session: 5, Player: 0, Trial List Length: 45, Updated List Length: 45
# Completed: Session 5
# Session: 6, Player: 0, Trial List Length: 48, Updated List Length: 48
# Completed: Session 6
# Session: 7, Player: 0, Trial List Length: 44, Updated List Length: 44
# Completed: Session 7
# Session: 8, Player: 0, Trial List Length: 47, Updated List Length: 47
# Completed: Session 8
# Session: 9, Player: 0, Trial List Length: 55, Updated List Length: 55
# Completed: Session 9
# Session: 10, Player: 0, Trial List Length: 56, Updated List Length: 56
# Completed: Session 10
# Session: 11, Player: 0, Trial List Length: 62, Updated List Length: 62
# Completed: Session 11
# Session: 12, Player: 0, Trial List Length: 52, Updated List Length: 52
# Completed: Session 12
# Session: 13, Player: 0, Trial List Length: 42, Updated List Length: 42
# Completed: Session 13
# Session: 14, Player: 0, Trial List Length: 45, Updated List Length: 45
# Completed: Session 14
# Session: 15, Player: 0, Trial List Length: 47, Updated List Length: 47
# Completed: Session 15
# Session: 16, Player: 0, Trial List Length: 47, Updated List Length: 47
# Completed: Session 16
# Session: 17, Player: 0, Trial List Length: 56, Updated List Length: 56
# Completed: Session 17
# Session: 18, Player: 0, Trial List Length: 64, Updated List Length: 64
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Thetas empty, skipping trial
# Completed: Session 18
# Session: 19, Player: 0, Trial List Length: 45, Updated List Length: 45
# Completed: Session 19
# Session: 20, Player: 0, Trial List Length: 52, Updated List Length: 52
# Completed: Session 20
# Session: 21, Player: 0, Trial List Length: 50, Updated List Length: 50
# Completed: Session 21
# Session: 22, Player: 0, Trial List Length: 67, Updated List Length: 67
# Completed: Session 22
# Session: 23, Player: 0, Trial List Length: 47, Updated List Length: 47
# Completed: Session 23
# Session: 24, Player: 0, Trial List Length: 51, Updated List Length: 51
# Completed: Session 24
# Session: 25, Player: 0, Trial List Length: 49, Updated List Length: 49
# Completed: Session 25
# Session: 26, Player: 0, Trial List Length: 47, Updated List Length: 47
# Completed: Session 26
# Session: 27, Player: 0, Trial List Length: 47, Updated List Length: 47
# Completed: Session 27
# Session: 28, Player: 0, Trial List Length: 46, Updated List Length: 46
# Completed: Session 28
# Session: 29, Player: 0, Trial List Length: 29, Updated List Length: 29
# Completed: Session 29
# Session: 30, Player: 0, Trial List Length: 51, Updated List Length: 51
# Completed: Session 30
# Session: 31, Player: 0, Trial List Length: 58, Updated List Length: 58
# Completed: Session 31
# Session: 32, Player: 0, Trial List Length: 42, Updated List Length: 42
# Completed: Session 32
# Session: 33, Player: 0, Trial List Length: 52, Updated List Length: 52
# Completed: Session 33
# Session: 34, Player: 0, Trial List Length: 60, Updated List Length: 60
# Completed: Session 34
# Session: 35, Player: 0, Trial List Length: 55, Updated List Length: 55
# Completed: Session 35
# Session: 36, Player: 0, Trial List Length: 49, Updated List Length: 49
# Completed: Session 36

# %%
from collections import defaultdict

total_counts_trials = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: {'by_bin': {'total_counts': 0}}))))
true_counts_trials = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: {'by_bin': {'true_counts': 0}}))))

# loop over the filtered trials
for session_id in filtered_trials_nominator:
    
    for bin_id in range(1,9):

        total_count = 0
        true_count = 0

        player_ids = [0]
    
        for player_id in player_ids:
            trial_list_filtered_true = filtered_trials_nominator[session_id]['by_player'][player_id][bin_id]
            trial_list_filtered = filtered_trials_denominator[session_id]['by_player'][player_id][bin_id]

            total_count += len(trial_list_filtered)
            true_count += len(trial_list_filtered_true)
            

        # store the final counts for total and true trials
        total_counts_trials[session_id]['by_bin'][bin_id]['total_counts'] = total_count
        true_counts_trials[session_id]['by_bin'][bin_id]['true_counts'] = true_count

        # debug Output
        print(f"Session {session_id}, Bin {bin_id}:")
        print(f"   ➤ Total Trials = {total_count}")
        print(f"   ➤ True Trials = {true_count}")
# Out:
# Session 0, Bin 1:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 0, Bin 2:
#    ➤ Total Trials = 8
#    ➤ True Trials = 6
# Session 0, Bin 3:
#    ➤ Total Trials = 11
#    ➤ True Trials = 5
# Session 0, Bin 4:
#    ➤ Total Trials = 3
#    ➤ True Trials = 2
# Session 0, Bin 5:
#    ➤ Total Trials = 13
#    ➤ True Trials = 9
# Session 0, Bin 6:
#    ➤ Total Trials = 6
#    ➤ True Trials = 4
# Session 0, Bin 7:
#    ➤ Total Trials = 7
#    ➤ True Trials = 5
# Session 0, Bin 8:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 1, Bin 1:
#    ➤ Total Trials = 11
#    ➤ True Trials = 9
# Session 1, Bin 2:
#    ➤ Total Trials = 15
#    ➤ True Trials = 15
# Session 1, Bin 3:
#    ➤ Total Trials = 11
#    ➤ True Trials = 11
# Session 1, Bin 4:
#    ➤ Total Trials = 8
#    ➤ True Trials = 7
# Session 1, Bin 5:
#    ➤ Total Trials = 7
#    ➤ True Trials = 6
# Session 1, Bin 6:
#    ➤ Total Trials = 11
#    ➤ True Trials = 10
# Session 1, Bin 7:
#    ➤ Total Trials = 13
#    ➤ True Trials = 10
# Session 1, Bin 8:
#    ➤ Total Trials = 5
#    ➤ True Trials = 3
# Session 2, Bin 1:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 2, Bin 2:
#    ➤ Total Trials = 9
#    ➤ True Trials = 9
# Session 2, Bin 3:
#    ➤ Total Trials = 9
#    ➤ True Trials = 8
# Session 2, Bin 4:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 2, Bin 5:
#    ➤ Total Trials = 10
#    ➤ True Trials = 8
# Session 2, Bin 6:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 2, Bin 7:
#    ➤ Total Trials = 3
#    ➤ True Trials = 3
# Session 2, Bin 8:
#    ➤ Total Trials = 7
#    ➤ True Trials = 7
# Session 3, Bin 1:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 3, Bin 2:
#    ➤ Total Trials = 6
#    ➤ True Trials = 5
# Session 3, Bin 3:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 3, Bin 4:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 3, Bin 5:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 3, Bin 6:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 3, Bin 7:
#    ➤ Total Trials = 7
#    ➤ True Trials = 7
# Session 3, Bin 8:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 4, Bin 1:
#    ➤ Total Trials = 12
#    ➤ True Trials = 12
# Session 4, Bin 2:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 4, Bin 3:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 4, Bin 4:
#    ➤ Total Trials = 9
#    ➤ True Trials = 7
# Session 4, Bin 5:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 4, Bin 6:
#    ➤ Total Trials = 11
#    ➤ True Trials = 10
# Session 4, Bin 7:
#    ➤ Total Trials = 12
#    ➤ True Trials = 12
# Session 4, Bin 8:
#    ➤ Total Trials = 13
#    ➤ True Trials = 13
# Session 5, Bin 1:
#    ➤ Total Trials = 4
#    ➤ True Trials = 3
# Session 5, Bin 2:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 5, Bin 3:
#    ➤ Total Trials = 3
#    ➤ True Trials = 3
# Session 5, Bin 4:
#    ➤ Total Trials = 5
#    ➤ True Trials = 3
# Session 5, Bin 5:
#    ➤ Total Trials = 4
#    ➤ True Trials = 3
# Session 5, Bin 6:
#    ➤ Total Trials = 7
#    ➤ True Trials = 7
# Session 5, Bin 7:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 5, Bin 8:
#    ➤ Total Trials = 12
#    ➤ True Trials = 11
# Session 6, Bin 1:
#    ➤ Total Trials = 6
#    ➤ True Trials = 5
# Session 6, Bin 2:
#    ➤ Total Trials = 6
#    ➤ True Trials = 5
# Session 6, Bin 3:
#    ➤ Total Trials = 6
#    ➤ True Trials = 5
# Session 6, Bin 4:
#    ➤ Total Trials = 4
#    ➤ True Trials = 2
# Session 6, Bin 5:
#    ➤ Total Trials = 4
#    ➤ True Trials = 0
# Session 6, Bin 6:
#    ➤ Total Trials = 9
#    ➤ True Trials = 8
# Session 6, Bin 7:
#    ➤ Total Trials = 3
#    ➤ True Trials = 2
# Session 6, Bin 8:
#    ➤ Total Trials = 10
#    ➤ True Trials = 9
# Session 7, Bin 1:
#    ➤ Total Trials = 1
#    ➤ True Trials = 1
# Session 7, Bin 2:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 7, Bin 3:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 7, Bin 4:
#    ➤ Total Trials = 6
#    ➤ True Trials = 5
# Session 7, Bin 5:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 7, Bin 6:
#    ➤ Total Trials = 7
#    ➤ True Trials = 7
# Session 7, Bin 7:
#    ➤ Total Trials = 7
#    ➤ True Trials = 6
# Session 7, Bin 8:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 8, Bin 1:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 8, Bin 2:
#    ➤ Total Trials = 3
#    ➤ True Trials = 3
# Session 8, Bin 3:
#    ➤ Total Trials = 3
#    ➤ True Trials = 1
# Session 8, Bin 4:
#    ➤ Total Trials = 9
#    ➤ True Trials = 4
# Session 8, Bin 5:
#    ➤ Total Trials = 5
#    ➤ True Trials = 2
# Session 8, Bin 6:
#    ➤ Total Trials = 8
#    ➤ True Trials = 4
# Session 8, Bin 7:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 8, Bin 8:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 9, Bin 1:
#    ➤ Total Trials = 3
#    ➤ True Trials = 3
# Session 9, Bin 2:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 9, Bin 3:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 9, Bin 4:
#    ➤ Total Trials = 4
#    ➤ True Trials = 1
# Session 9, Bin 5:
#    ➤ Total Trials = 7
#    ➤ True Trials = 5
# Session 9, Bin 6:
#    ➤ Total Trials = 7
#    ➤ True Trials = 7
# Session 9, Bin 7:
#    ➤ Total Trials = 11
#    ➤ True Trials = 10
# Session 9, Bin 8:
#    ➤ Total Trials = 12
#    ➤ True Trials = 12
# Session 10, Bin 1:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 10, Bin 2:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 10, Bin 3:
#    ➤ Total Trials = 7
#    ➤ True Trials = 2
# Session 10, Bin 4:
#    ➤ Total Trials = 13
#    ➤ True Trials = 2
# Session 10, Bin 5:
#    ➤ Total Trials = 9
#    ➤ True Trials = 6
# Session 10, Bin 6:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 10, Bin 7:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 10, Bin 8:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 11, Bin 1:
#    ➤ Total Trials = 9
#    ➤ True Trials = 9
# Session 11, Bin 2:
#    ➤ Total Trials = 8
#    ➤ True Trials = 7
# Session 11, Bin 3:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 11, Bin 4:
#    ➤ Total Trials = 9
#    ➤ True Trials = 6
# Session 11, Bin 5:
#    ➤ Total Trials = 6
#    ➤ True Trials = 4
# Session 11, Bin 6:
#    ➤ Total Trials = 12
#    ➤ True Trials = 11
# Session 11, Bin 7:
#    ➤ Total Trials = 9
#    ➤ True Trials = 9
# Session 11, Bin 8:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 12, Bin 1:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 12, Bin 2:
#    ➤ Total Trials = 7
#    ➤ True Trials = 7
# Session 12, Bin 3:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 12, Bin 4:
#    ➤ Total Trials = 7
#    ➤ True Trials = 6
# Session 12, Bin 5:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 12, Bin 6:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 12, Bin 7:
#    ➤ Total Trials = 8
#    ➤ True Trials = 7
# Session 12, Bin 8:
#    ➤ Total Trials = 7
#    ➤ True Trials = 7
# Session 13, Bin 1:
#    ➤ Total Trials = 2
#    ➤ True Trials = 2
# Session 13, Bin 2:
#    ➤ Total Trials = 3
#    ➤ True Trials = 3
# Session 13, Bin 3:
#    ➤ Total Trials = 11
#    ➤ True Trials = 10
# Session 13, Bin 4:
#    ➤ Total Trials = 6
#    ➤ True Trials = 5
# Session 13, Bin 5:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 13, Bin 6:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 13, Bin 7:
#    ➤ Total Trials = 3
#    ➤ True Trials = 3
# Session 13, Bin 8:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 14, Bin 1:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 14, Bin 2:
#    ➤ Total Trials = 3
#    ➤ True Trials = 3
# Session 14, Bin 3:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 14, Bin 4:
#    ➤ Total Trials = 6
#    ➤ True Trials = 5
# Session 14, Bin 5:
#    ➤ Total Trials = 8
#    ➤ True Trials = 7
# Session 14, Bin 6:
#    ➤ Total Trials = 6
#    ➤ True Trials = 4
# Session 14, Bin 7:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 14, Bin 8:
#    ➤ Total Trials = 7
#    ➤ True Trials = 7
# Session 15, Bin 1:
#    ➤ Total Trials = 7
#    ➤ True Trials = 7
# Session 15, Bin 2:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 15, Bin 3:
#    ➤ Total Trials = 9
#    ➤ True Trials = 4
# Session 15, Bin 4:
#    ➤ Total Trials = 6
#    ➤ True Trials = 5
# Session 15, Bin 5:
#    ➤ Total Trials = 5
#    ➤ True Trials = 3
# Session 15, Bin 6:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 15, Bin 7:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 15, Bin 8:
#    ➤ Total Trials = 3
#    ➤ True Trials = 2
# Session 16, Bin 1:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 16, Bin 2:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 16, Bin 3:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 16, Bin 4:
#    ➤ Total Trials = 8
#    ➤ True Trials = 7
# Session 16, Bin 5:
#    ➤ Total Trials = 7
#    ➤ True Trials = 3
# Session 16, Bin 6:
#    ➤ Total Trials = 6
#    ➤ True Trials = 2
# Session 16, Bin 7:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 16, Bin 8:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 17, Bin 1:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 17, Bin 2:
#    ➤ Total Trials = 9
#    ➤ True Trials = 9
# Session 17, Bin 3:
#    ➤ Total Trials = 6
#    ➤ True Trials = 3
# Session 17, Bin 4:
#    ➤ Total Trials = 13
#    ➤ True Trials = 13
# Session 17, Bin 5:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 17, Bin 6:
#    ➤ Total Trials = 8
#    ➤ True Trials = 5
# Session 17, Bin 7:
#    ➤ Total Trials = 1
#    ➤ True Trials = 1
# Session 17, Bin 8:
#    ➤ Total Trials = 7
#    ➤ True Trials = 7
# Session 18, Bin 1:
#    ➤ Total Trials = 12
#    ➤ True Trials = 10
# Session 18, Bin 2:
#    ➤ Total Trials = 9
#    ➤ True Trials = 5
# Session 18, Bin 3:
#    ➤ Total Trials = 6
#    ➤ True Trials = 3
# Session 18, Bin 4:
#    ➤ Total Trials = 6
#    ➤ True Trials = 2
# Session 18, Bin 5:
#    ➤ Total Trials = 9
#    ➤ True Trials = 2
# Session 18, Bin 6:
#    ➤ Total Trials = 4
#    ➤ True Trials = 2
# Session 18, Bin 7:
#    ➤ Total Trials = 7
#    ➤ True Trials = 1
# Session 18, Bin 8:
#    ➤ Total Trials = 10
#    ➤ True Trials = 7
# Session 19, Bin 1:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 19, Bin 2:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 19, Bin 3:
#    ➤ Total Trials = 10
#    ➤ True Trials = 10
# Session 19, Bin 4:
#    ➤ Total Trials = 4
#    ➤ True Trials = 2
# Session 19, Bin 5:
#    ➤ Total Trials = 3
#    ➤ True Trials = 3
# Session 19, Bin 6:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 19, Bin 7:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 19, Bin 8:
#    ➤ Total Trials = 2
#    ➤ True Trials = 2
# Session 20, Bin 1:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 20, Bin 2:
#    ➤ Total Trials = 3
#    ➤ True Trials = 3
# Session 20, Bin 3:
#    ➤ Total Trials = 12
#    ➤ True Trials = 10
# Session 20, Bin 4:
#    ➤ Total Trials = 7
#    ➤ True Trials = 6
# Session 20, Bin 5:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 20, Bin 6:
#    ➤ Total Trials = 7
#    ➤ True Trials = 4
# Session 20, Bin 7:
#    ➤ Total Trials = 11
#    ➤ True Trials = 10
# Session 20, Bin 8:
#    ➤ Total Trials = 2
#    ➤ True Trials = 2
# Session 21, Bin 1:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 21, Bin 2:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 21, Bin 3:
#    ➤ Total Trials = 6
#    ➤ True Trials = 2
# Session 21, Bin 4:
#    ➤ Total Trials = 9
#    ➤ True Trials = 5
# Session 21, Bin 5:
#    ➤ Total Trials = 6
#    ➤ True Trials = 3
# Session 21, Bin 6:
#    ➤ Total Trials = 6
#    ➤ True Trials = 3
# Session 21, Bin 7:
#    ➤ Total Trials = 4
#    ➤ True Trials = 3
# Session 21, Bin 8:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 22, Bin 1:
#    ➤ Total Trials = 9
#    ➤ True Trials = 9
# Session 22, Bin 2:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 22, Bin 3:
#    ➤ Total Trials = 8
#    ➤ True Trials = 4
# Session 22, Bin 4:
#    ➤ Total Trials = 7
#    ➤ True Trials = 5
# Session 22, Bin 5:
#    ➤ Total Trials = 9
#    ➤ True Trials = 8
# Session 22, Bin 6:
#    ➤ Total Trials = 7
#    ➤ True Trials = 6
# Session 22, Bin 7:
#    ➤ Total Trials = 12
#    ➤ True Trials = 12
# Session 22, Bin 8:
#    ➤ Total Trials = 9
#    ➤ True Trials = 9
# Session 23, Bin 1:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 23, Bin 2:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 23, Bin 3:
#    ➤ Total Trials = 11
#    ➤ True Trials = 11
# Session 23, Bin 4:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 23, Bin 5:
#    ➤ Total Trials = 2
#    ➤ True Trials = 2
# Session 23, Bin 6:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 23, Bin 7:
#    ➤ Total Trials = 6
#    ➤ True Trials = 4
# Session 23, Bin 8:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 24, Bin 1:
#    ➤ Total Trials = 9
#    ➤ True Trials = 9
# Session 24, Bin 2:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 24, Bin 3:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 24, Bin 4:
#    ➤ Total Trials = 9
#    ➤ True Trials = 9
# Session 24, Bin 5:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 24, Bin 6:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 24, Bin 7:
#    ➤ Total Trials = 6
#    ➤ True Trials = 5
# Session 24, Bin 8:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 25, Bin 1:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 25, Bin 2:
#    ➤ Total Trials = 8
#    ➤ True Trials = 7
# Session 25, Bin 3:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 25, Bin 4:
#    ➤ Total Trials = 4
#    ➤ True Trials = 3
# Session 25, Bin 5:
#    ➤ Total Trials = 2
#    ➤ True Trials = 2
# Session 25, Bin 6:
#    ➤ Total Trials = 9
#    ➤ True Trials = 7
# Session 25, Bin 7:
#    ➤ Total Trials = 11
#    ➤ True Trials = 11
# Session 25, Bin 8:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 26, Bin 1:
#    ➤ Total Trials = 9
#    ➤ True Trials = 9
# Session 26, Bin 2:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 26, Bin 3:
#    ➤ Total Trials = 3
#    ➤ True Trials = 3
# Session 26, Bin 4:
#    ➤ Total Trials = 10
#    ➤ True Trials = 5
# Session 26, Bin 5:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 26, Bin 6:
#    ➤ Total Trials = 2
#    ➤ True Trials = 2
# Session 26, Bin 7:
#    ➤ Total Trials = 4
#    ➤ True Trials = 3
# Session 26, Bin 8:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 27, Bin 1:
#    ➤ Total Trials = 2
#    ➤ True Trials = 2
# Session 27, Bin 2:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 27, Bin 3:
#    ➤ Total Trials = 9
#    ➤ True Trials = 9
# Session 27, Bin 4:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 27, Bin 5:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 27, Bin 6:
#    ➤ Total Trials = 7
#    ➤ True Trials = 6
# Session 27, Bin 7:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 27, Bin 8:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 28, Bin 1:
#    ➤ Total Trials = 8
#    ➤ True Trials = 7
# Session 28, Bin 2:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 28, Bin 3:
#    ➤ Total Trials = 4
#    ➤ True Trials = 3
# Session 28, Bin 4:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 28, Bin 5:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 28, Bin 6:
#    ➤ Total Trials = 7
#    ➤ True Trials = 7
# Session 28, Bin 7:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 28, Bin 8:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 29, Bin 1:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 29, Bin 2:
#    ➤ Total Trials = 3
#    ➤ True Trials = 2
# Session 29, Bin 3:
#    ➤ Total Trials = 4
#    ➤ True Trials = 2
# Session 29, Bin 4:
#    ➤ Total Trials = 4
#    ➤ True Trials = 2
# Session 29, Bin 5:
#    ➤ Total Trials = 1
#    ➤ True Trials = 0
# Session 29, Bin 6:
#    ➤ Total Trials = 3
#    ➤ True Trials = 2
# Session 29, Bin 7:
#    ➤ Total Trials = 2
#    ➤ True Trials = 2
# Session 29, Bin 8:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 30, Bin 1:
#    ➤ Total Trials = 7
#    ➤ True Trials = 6
# Session 30, Bin 2:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 30, Bin 3:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 30, Bin 4:
#    ➤ Total Trials = 13
#    ➤ True Trials = 12
# Session 30, Bin 5:
#    ➤ Total Trials = 3
#    ➤ True Trials = 3
# Session 30, Bin 6:
#    ➤ Total Trials = 3
#    ➤ True Trials = 3
# Session 30, Bin 7:
#    ➤ Total Trials = 7
#    ➤ True Trials = 7
# Session 30, Bin 8:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 31, Bin 1:
#    ➤ Total Trials = 7
#    ➤ True Trials = 6
# Session 31, Bin 2:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 31, Bin 3:
#    ➤ Total Trials = 7
#    ➤ True Trials = 3
# Session 31, Bin 4:
#    ➤ Total Trials = 5
#    ➤ True Trials = 2
# Session 31, Bin 5:
#    ➤ Total Trials = 12
#    ➤ True Trials = 9
# Session 31, Bin 6:
#    ➤ Total Trials = 6
#    ➤ True Trials = 5
# Session 31, Bin 7:
#    ➤ Total Trials = 10
#    ➤ True Trials = 9
# Session 31, Bin 8:
#    ➤ Total Trials = 3
#    ➤ True Trials = 3
# Session 32, Bin 1:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 32, Bin 2:
#    ➤ Total Trials = 5
#    ➤ True Trials = 4
# Session 32, Bin 3:
#    ➤ Total Trials = 4
#    ➤ True Trials = 3
# Session 32, Bin 4:
#    ➤ Total Trials = 5
#    ➤ True Trials = 3
# Session 32, Bin 5:
#    ➤ Total Trials = 5
#    ➤ True Trials = 5
# Session 32, Bin 6:
#    ➤ Total Trials = 4
#    ➤ True Trials = 3
# Session 32, Bin 7:
#    ➤ Total Trials = 5
#    ➤ True Trials = 3
# Session 32, Bin 8:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 33, Bin 1:
#    ➤ Total Trials = 3
#    ➤ True Trials = 3
# Session 33, Bin 2:
#    ➤ Total Trials = 13
#    ➤ True Trials = 12
# Session 33, Bin 3:
#    ➤ Total Trials = 5
#    ➤ True Trials = 2
# Session 33, Bin 4:
#    ➤ Total Trials = 5
#    ➤ True Trials = 2
# Session 33, Bin 5:
#    ➤ Total Trials = 6
#    ➤ True Trials = 4
# Session 33, Bin 6:
#    ➤ Total Trials = 3
#    ➤ True Trials = 2
# Session 33, Bin 7:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 33, Bin 8:
#    ➤ Total Trials = 9
#    ➤ True Trials = 9
# Session 34, Bin 1:
#    ➤ Total Trials = 10
#    ➤ True Trials = 9
# Session 34, Bin 2:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 34, Bin 3:
#    ➤ Total Trials = 7
#    ➤ True Trials = 6
# Session 34, Bin 4:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 34, Bin 5:
#    ➤ Total Trials = 8
#    ➤ True Trials = 8
# Session 34, Bin 6:
#    ➤ Total Trials = 7
#    ➤ True Trials = 5
# Session 34, Bin 7:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 34, Bin 8:
#    ➤ Total Trials = 6
#    ➤ True Trials = 5
# Session 35, Bin 1:
#    ➤ Total Trials = 7
#    ➤ True Trials = 7
# Session 35, Bin 2:
#    ➤ Total Trials = 6
#    ➤ True Trials = 5
# Session 35, Bin 3:
#    ➤ Total Trials = 5
#    ➤ True Trials = 3
# Session 35, Bin 4:
#    ➤ Total Trials = 6
#    ➤ True Trials = 5
# Session 35, Bin 5:
#    ➤ Total Trials = 8
#    ➤ True Trials = 5
# Session 35, Bin 6:
#    ➤ Total Trials = 7
#    ➤ True Trials = 5
# Session 35, Bin 7:
#    ➤ Total Trials = 10
#    ➤ True Trials = 9
# Session 35, Bin 8:
#    ➤ Total Trials = 6
#    ➤ True Trials = 4
# Session 36, Bin 1:
#    ➤ Total Trials = 6
#    ➤ True Trials = 6
# Session 36, Bin 2:
#    ➤ Total Trials = 4
#    ➤ True Trials = 4
# Session 36, Bin 3:
#    ➤ Total Trials = 9
#    ➤ True Trials = 3
# Session 36, Bin 4:
#    ➤ Total Trials = 7
#    ➤ True Trials = 1
# Session 36, Bin 5:
#    ➤ Total Trials = 4
#    ➤ True Trials = 1
# Session 36, Bin 6:
#    ➤ Total Trials = 4
#    ➤ True Trials = 1
# Session 36, Bin 7:
#    ➤ Total Trials = 6
#    ➤ True Trials = 5
# Session 36, Bin 8:
#    ➤ Total Trials = 9
#    ➤ True Trials = 9

# %%
# initialize the dictionary to store aggregated counts across all sessions
aggregated_counts = defaultdict(lambda: {'true_counts': 0, 'total_counts': 0})

# initialize the dictionaries to store overall probabilities and bin probabilities
overall_probabilities = defaultdict(lambda: defaultdict(float))  # stores overall probabilities
bin_probabilities = defaultdict(lambda: defaultdict(dict))  # stores bin probabilities

# calculate the aggregated counts across all sessions
for session_id in total_counts_trials:
    
    for bin_id in range(1, 9):  # iterate over bins (1 to 8)
        true_counts = true_counts_trials[session_id]['by_bin'][bin_id]['true_counts']
        total_counts = total_counts_trials[session_id]['by_bin'][bin_id]['total_counts']

        # accumulate the counts for each bin across sessions
        aggregated_counts[bin_id]['true_counts'] += true_counts
        aggregated_counts[bin_id]['total_counts'] += total_counts

for bin_id in range(1,9):
    if aggregated_counts[bin_id]['true_counts'] > 0:
        total_true_counts = sum(aggregated_counts[bin_id]['true_counts']for bin_id in range(1, 9))
        print(total_true_counts)
        total_total_counts = sum(aggregated_counts[bin_id]['total_counts']for bin_id in range(1, 9))
        print(total_total_counts)


# compute overall probability
overall_probability = total_true_counts / total_total_counts if total_total_counts > 0 else None

# calculate the probability for each bin across all sessions
probabilities_by_bin = [] # list to store probabilities for each bin
total_counts_by_bin = []
true_counts_by_bin = []
probabilities_dict = {}  

for bin_id in range(1, 9):  # iterate over bins (1 to 8)
    true_counts = aggregated_counts[bin_id]['true_counts']
    total_counts = aggregated_counts[bin_id]['total_counts']

    if total_counts > 20:
        probability_chose_high_by_bin = true_counts / total_counts
        probabilities_dict[bin_id] = probability_chose_high_by_bin
        probabilities_by_bin.append(probability_chose_high_by_bin)
        total_counts_by_bin.append(total_counts)
        true_counts_by_bin.append(true_counts)

    else:
        probabilities_dict[bin_id] = None
        probabilities_by_bin.append(None)  # add None if total count is 0
        print(f"Total count is 0 for bin {bin_id}, adding probability of None")
        total_counts_by_bin.append(total_counts)
        true_counts_by_bin.append(true_counts)
        

bin_probabilities = probabilities_dict

print(f"Probabilities for each bin: {probabilities_by_bin}")
print(overall_probability)
# Out:
# 1631
# 1930
# 1631
# 1930
# 1631
# 1930
# 1631
# 1930
# 1631
# 1930
# 1631
# 1930
# 1631
# 1930
# 1631
# 1930
# Probabilities for each bin: [0.9539748953974896, 0.9388646288209607, 0.7609561752988048, 0.6984126984126984, 0.7695652173913043, 0.8158995815899581, 0.8835341365461847, 0.950207468879668]
# 0.8450777202072539

# %%
#do this for each
probabilities_list = []
for probability in probabilities_by_bin:
    if probability != None:
        probabilities_list.append(probability-overall_probability)
    else: probabilities_list.append(np.nan)

# %%
print(probabilities_list)
# Out:
# [0.1696309212438245, 0.1718641718641719, 0.0011505481384999072, -0.2264264264264264, -0.1849670566088477, -0.19468039468039466, 0.1084289769221276, 0.16087516087516085]

# %%
bin_ranges = headangle_bin_assignment_new.define_45_degree_bins()
print(bin_ranges)
# Out:
# [(np.float64(5.8904862254808625), np.float64(0.3926990816987242)), (np.float64(0.39269908169872414), np.float64(1.1780972450961724)), (np.float64(1.1780972450961726), np.float64(1.963495408493621)), (np.float64(1.9634954084936211), np.float64(2.7488935718910694)), (np.float64(2.748893571891069), np.float64(3.5342917352885173)), (np.float64(3.5342917352885173), np.float64(4.319689898685965)), (np.float64(4.319689898685965), np.float64(5.105088062083414)), (np.float64(5.105088062083414), np.float64(5.890486225480862))]

# %%
probabilities_list_45_solo=probabilities_list
total_counts_by_bin_45_solo=total_counts_by_bin
true_counts_by_bin_45_solo=true_counts_by_bin
overall_probability_45_solo=overall_probability

# %%
probabilities_list_90_solo=probabilities_list
total_counts_by_bin_90_solo=total_counts_by_bin
true_counts_by_bin_90_solo=true_counts_by_bin
overall_probability_90_solo=overall_probability

# %%
probabilities_list_180_solo=probabilities_list
total_counts_by_bin_180_solo=total_counts_by_bin
true_counts_by_bin_180_solo=true_counts_by_bin
overall_probability_180_solo=overall_probability

# %%
probabilities_list_solo=probabilities_list
total_counts_by_bin_solo=total_counts_by_bin
true_counts_by_bin_solo=true_counts_by_bin
overall_probability_solo=overall_probability

# %%
# %store probabilities_list_45_solo
# %store total_counts_by_bin_45_solo
# %store true_counts_by_bin_45_solo
# %store overall_probability_45_solo
# Out:
# Stored 'probabilities_list_45_solo' (list)
# Stored 'total_counts_by_bin_45_solo' (list)
# Stored 'true_counts_by_bin_45_solo' (list)
# Stored 'overall_probability_45_solo' (float)

# %%
print(probabilities_list_45_solo)
print(total_counts_by_bin_45_solo)
# Out:
# [0.032273505091722776, 0.01543160478019634, -0.0898695503353153, -0.05609617299758152, 0.0032418884681395532, 0.035250926314119635, 0.00043618353477503646, 0.05464040627832367]
# [107, 96, 101, 90, 94, 113, 91, 89]

# %%
# %store probabilities_list_90_solo
# %store total_counts_by_bin_90_solo
# %store true_counts_by_bin_90_solo
# %store overall_probability_90_solo
# Out:
# Stored 'probabilities_list_90_solo' (list)
# Stored 'total_counts_by_bin_90_solo' (list)
# Stored 'true_counts_by_bin_90_solo' (list)
# Stored 'overall_probability_90_solo' (float)

# %%
print(probabilities_list_90_solo)
# Out:
# [0.15382857142857143, 0.12906666666666666, -0.14192432432432434, -0.16135, -0.09760000000000002, -0.005099999999999993, 0.03123720930232554, 0.12357647058823529]

# %%
# %store probabilities_list_180_solo
# %store total_counts_by_bin_180_solo
# %store true_counts_by_bin_180_solo
# %store overall_probability_180_solo
# Out:
# Stored 'probabilities_list_180_solo' (list)
# Stored 'total_counts_by_bin_180_solo' (list)
# Stored 'true_counts_by_bin_180_solo' (list)
# Stored 'overall_probability_180_solo' (float)

# %%
print(probabilities_list_180_solo)
# Out:
# [0.17298694902733325, 0.16964990787049228, -0.0154680594616311, -0.23317140874392783, -0.1720685771492929, -0.19798079290815063, 0.11026293469041559, 0.16167255326421337]

# %%
# %store probabilities_list_solo
# %store total_counts_by_bin_solo
# %store true_counts_by_bin_solo
# %store overall_probability_solo
# Out:
# Stored 'probabilities_list_solo' (list)
# Stored 'total_counts_by_bin_solo' (list)
# Stored 'true_counts_by_bin_solo' (list)
# Stored 'overall_probability_solo' (float)

# %%
bin_ranges = headangle_bin_assignment_new.define_45_degree_bins()
print(bin_ranges)
# Out:
# [(np.float64(5.8904862254808625), np.float64(0.3926990816987242)), (np.float64(0.39269908169872414), np.float64(1.1780972450961724)), (np.float64(1.1780972450961726), np.float64(1.963495408493621)), (np.float64(1.9634954084936211), np.float64(2.7488935718910694)), (np.float64(2.748893571891069), np.float64(3.5342917352885173)), (np.float64(3.5342917352885173), np.float64(4.319689898685965)), (np.float64(4.319689898685965), np.float64(5.105088062083414)), (np.float64(5.105088062083414), np.float64(5.890486225480862))]

# %%
lists = [probabilities_list_45_solo, probabilities_list_90_solo, probabilities_list_180_solo, probabilities_list_solo]
all_ratios = [x for sublist in lists for x in sublist]

all_ratios = [x for x in all_ratios if x is not None and not (isinstance(x, float) and math.isnan(x))]

print(all_ratios)
# Out:
# [0.032273505091722776, 0.01543160478019634, -0.0898695503353153, -0.05609617299758152, 0.0032418884681395532, 0.035250926314119635, 0.00043618353477503646, 0.05464040627832367, 0.15382857142857143, 0.12906666666666666, -0.14192432432432434, -0.16135, -0.09760000000000002, -0.005099999999999993, 0.03123720930232554, 0.12357647058823529, 0.17298694902733325, 0.16964990787049228, -0.0154680594616311, -0.23317140874392783, -0.1720685771492929, -0.19798079290815063, 0.11026293469041559, 0.16167255326421337, 0.10889717519023567, 0.09378690861370675, -0.08412154490844914, -0.14666502179455554, -0.07551250281594957, -0.02917813861729579, 0.03845641633893082, 0.10512974867241409]

# %%
import matplotlib.ticker as ticker
fig, ax = plt.subplots(figsize=(6,6))

#plot octagon
ax = plot_octagon.plot_octagon(ax=ax)

#define bin_ranges
bin_ranges = bin_ranges


#color the segments of the octagon
ax = headangle_analysis_plotting_functions.plot_colored_octagon(ax, bin_ranges, probabilities_list_45_solo, all_ratios)

#plot the ratios under the alcoves
ax = headangle_analysis_plotting_functions.plot_ratios_under_alcoves(ax, total_counts_by_bin_45_solo, probabilities_list_45_solo)

#ax = headangle_analysis_plotting_functions.plot_counts_in_bins(ax, total_counts_by_bin_45_solo, true_counts_by_bin_45_solo)


#add wall labels
alcove_centers = plot_octagon.return_alcove_centre_points()

alcove_center1_x, alcove_center1_y = alcove_centers[:,0]
alcove_center2_x, alcove_center2_y = alcove_centers[:,1]

ax.text(alcove_center1_x, alcove_center1_y + 5, f'{"High"}', 
                ha='center', va='center', fontsize=14, color='Red')
ax.text(alcove_center2_x + 3, alcove_center2_y + 5, f'{"Low"}', 
                ha='center', va='center', fontsize=14, color='Blue')


#add a colorbar for reference
sm = plt.cm.ScalarMappable(cmap=plt.cm.viridis, norm=plt.Normalize(vmax=max(all_ratios), vmin=min(all_ratios)))
sm.set_array([])  # Only necessary for ScalarMappable
cbar = plt.colorbar(sm, ax=ax, shrink=0.8)
cbar.set_label("P(H) - avg(P(H))", fontsize=13, rotation=270, labelpad=15)

# Format the ticks on the color bar to show only 2 decimals
cbar.formatter = ticker.FuncFormatter(lambda x, _: f'{x:.2f}')
cbar.update_ticks()  # Update the ticks to apply the formatting

rounded_probability_45_solo = round(overall_probability_45_solo, 2)
plt.title(f"P(H) = {rounded_probability_45_solo}", fontsize=14)
plt.axis('equal')
plt.axis('off')
plt.show()
print("45° wall separation, combined solos")
# Out:
# (2, 8)
# 45° wall separation, combined solos

# %%
import matplotlib.ticker as ticker
fig, ax = plt.subplots(figsize=(6,6))

#plot octagon
ax = plot_octagon.plot_octagon(ax=ax)

#define bin_ranges
bin_ranges = bin_ranges


#color the segments of the octagon
ax = headangle_analysis_plotting_functions.plot_colored_octagon(ax, bin_ranges, probabilities_list_90_solo, all_ratios)

#plot the ratios under the alcoves
ax = headangle_analysis_plotting_functions.plot_ratios_under_alcoves(ax, total_counts_by_bin_90_solo, probabilities_list_90_solo)

#ax = headangle_analysis_plotting_functions.plot_counts_in_bins(ax, total_counts_by_bin_90_solo, true_counts_by_bin_90_solo)


#add wall labels
alcove_centers = plot_octagon.return_alcove_centre_points()

# Get the center of the third alcove
alcove_center2_x, alcove_center2_y = alcove_centers[:, 2]

# Adjust the position slightly to the right of the third alcove's center
ax.text(alcove_center2_x + 4, alcove_center2_y, f'{"Low"}', 
        ha='center', va='center', fontsize=14, color='Blue')

# Add the high wall label
alcove_center1_x, alcove_center1_y = alcove_centers[:, 0]
ax.text(alcove_center1_x, alcove_center1_y + 5, f'{"High"}', 
        ha='center', va='center', fontsize=14, color='Red')


#add a colorbar for reference
sm = plt.cm.ScalarMappable(cmap=plt.cm.viridis, norm=plt.Normalize(vmax=max(all_ratios), vmin=min(all_ratios)))
sm.set_array([])  # Only necessary for ScalarMappable
cbar = plt.colorbar(sm, ax=ax, shrink=0.8)
cbar.set_label("P(H) - avg(P(H))", fontsize=13, rotation=270, labelpad=15)

# Format the ticks on the color bar to show only 2 decimals
cbar.formatter = ticker.FuncFormatter(lambda x, _: f'{x:.2f}')
cbar.update_ticks()  # Update the ticks to apply the formatting

rounded_probability_90_solo = round(overall_probability_90_solo, 2)
plt.title(f"P(H) = {rounded_probability_90_solo}", fontsize=14)
plt.axis('equal')
plt.axis('off')
plt.show()
print("90° wall separation, combined solos")
# Out:
# (2, 8)
# 90° wall separation, combined solos

# %%
import matplotlib.ticker as ticker
fig, ax = plt.subplots(figsize=(6,6))

#plot octagon
ax = plot_octagon.plot_octagon(ax=ax)

#define bin_ranges
bin_ranges = bin_ranges


#color the segments of the octagon
ax = headangle_analysis_plotting_functions.plot_colored_octagon(ax, bin_ranges, probabilities_list_180_solo, all_ratios)

#plot the ratios under the alcoves
ax = headangle_analysis_plotting_functions.plot_ratios_under_alcoves(ax, total_counts_by_bin_180_solo, probabilities_list_180_solo)

#ax = headangle_analysis_plotting_functions.plot_counts_in_bins(ax, total_counts_by_bin_180_solo, true_counts_by_bin_180_solo)


#add wall labels
alcove_centers = plot_octagon.return_alcove_centre_points()

alcove_center1_x, alcove_center1_y = alcove_centers[:,0]
alcove_center4_x, alcove_center4_y = alcove_centers[:,4]

ax.text(alcove_center1_x, alcove_center1_y + 5, f'{"High"}', 
                ha='center', va='center', fontsize=14, color='Red')
ax.text(alcove_center4_x, alcove_center4_y - 5, f'{"Low"}', 
                ha='center', va='center', fontsize=14, color='Blue')


#add a colorbar for reference
sm = plt.cm.ScalarMappable(cmap=plt.cm.viridis, norm=plt.Normalize(vmax=max(all_ratios), vmin=min(all_ratios)))
sm.set_array([])  # Only necessary for ScalarMappable
cbar = plt.colorbar(sm, ax=ax, shrink=0.8)
cbar.set_label("P(H) - avg(P(H))", fontsize=13, rotation=270, labelpad=15)

# Format the ticks on the color bar to show only 2 decimals
cbar.formatter = ticker.FuncFormatter(lambda x, _: f'{x:.2f}')
cbar.update_ticks()  # Update the ticks to apply the formatting

rounded_probability_180_solo = round(overall_probability_180_solo, 2)
plt.title(f"P(H) = {rounded_probability_180_solo}", fontsize=14)
plt.axis('equal')
plt.axis('off')
plt.show()
print("180° wall separation, combined solos")
# Out:
# (2, 8)
# 180° wall separation, combined solos

# %%
import matplotlib.ticker as ticker
fig, ax = plt.subplots(figsize=(6,6))

#plot octagon
ax = plot_octagon.plot_octagon(ax=ax)

#define bin_ranges
bin_ranges = bin_ranges


#color the segments of the octagon
ax = headangle_analysis_plotting_functions.plot_colored_octagon(ax, bin_ranges, probabilities_list, all_ratios)

#plot the ratios under the alcoves
ax = headangle_analysis_plotting_functions.plot_ratios_under_alcoves(ax, total_counts_by_bin, probabilities_list)

#ax = headangle_analysis_plotting_functions.plot_counts_in_bins(ax, total_counts_by_bin, true_counts_by_bin)


#add a colorbar for reference
sm = plt.cm.ScalarMappable(cmap=plt.cm.viridis, norm=plt.Normalize(vmax=max(all_ratios), vmin=min(all_ratios)))
sm.set_array([])  # Only necessary for ScalarMappable
cbar = plt.colorbar(sm, ax=ax, shrink=0.8)
cbar.set_label("P(H) - avg(P(H))", fontsize=13, rotation=270, labelpad=15)

# Format the ticks on the color bar to show only 2 decimals
cbar.formatter = ticker.FuncFormatter(lambda x, _: f'{x:.2f}')
cbar.update_ticks()  # Update the ticks to apply the formatting

rounded_probability = round(overall_probability, 2)
plt.title(f"P(H) = {rounded_probability}", fontsize=14)
plt.axis('equal')
plt.axis('off')
plt.show()
print("wall separations combined, combined solos")
# Out:
# (2, 8)
# wall separations combined, combined solos
